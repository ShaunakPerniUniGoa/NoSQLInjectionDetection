# %%
import random
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_predict, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score

# %%
data = pd.read_csv("../Dataset/explored_dataset.csv")
X = data.drop(columns=['label', 'Unnamed: 0'])
Y = data[['label']]

# %%
classifiers = {
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(),
    "Support Vector Machine": SVC(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Decision Tree": DecisionTreeClassifier(),
    "Naive Bayes": GaussianNB()
}

# %%
# Function to evaluate with cross-validation
def evaluate_with_cv(model, X, Y, cv_splits=5):
    accuracy_scores = cross_val_score(model, X, Y, cv=cv_splits, scoring='accuracy')
    precision_scores = cross_val_score(model, X, Y, cv=cv_splits, scoring='precision')
    recall_scores = cross_val_score(model, X, Y, cv=cv_splits, scoring='recall')
    f1_scores = cross_val_score(model, X, Y, cv=cv_splits, scoring='f1')
    return accuracy_scores.mean(), precision_scores.mean(), recall_scores.mean(), f1_scores.mean()

# Function to train, evaluate and compute kappa scores
def evaluate_model(model, X_train, Y_train, X_val, Y_val):
    model.fit(X_train, Y_train)
    val_predictions = model.predict(X_val)
    accuracy = accuracy_score(Y_val, val_predictions)
    precision = precision_score(Y_val, val_predictions)
    recall = recall_score(Y_val, val_predictions)
    f1 = f1_score(Y_val, val_predictions)
    return accuracy, precision, recall, f1

# %%
results_per_seed = []
for random_state in range(51):  # Change 51 to your desired upper limit
    # Split data with current random_state
    X_train_full, X_test, Y_train_full, Y_test = train_test_split(X, Y, test_size=0.2, random_state=random_state)
    X_train, X_val, Y_train, Y_val = train_test_split(X_train_full, Y_train_full, test_size=0.2, random_state=random_state)
    
    # Store metrics for each model
    metrics_dict = {
        "random_state": random_state,
        "model_metrics": {}
    }
    
    for name, clf in classifiers.items():
        # Cross-validation evaluation
        accuracy_cv, precision_cv, recall_cv, f1_cv = evaluate_with_cv(clf, X_train, Y_train)
        
        # Model evaluation on validation set
        accuracy_val, precision_val, recall_val, f1_val = evaluate_model(clf, X_train, Y_train, X_val, Y_val)
        
        # Store the results for the classifier
        metrics_dict["model_metrics"][name] = {
            "accuracy_cv": accuracy_cv,
            "precision_cv": precision_cv,
            "recall_cv": recall_cv,
            "f1_cv": f1_cv,
            "accuracy_val": accuracy_val,
            "precision_val": precision_val,
            "recall_val": recall_val,
            "f1_val": f1_val
        }
    
    # Store the results for this random state
    results_per_seed.append(metrics_dict)
# Out:
# /home/shaunakperni/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/shaunakperni/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/shaunakperni/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/shaunakperni/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/shaunakperni/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/shaunakperni/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/shaunakperni/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/shaunakperni/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/shaunakperni/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/shaunakperni/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/shaunakperni/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/shaunakperni/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/shaunakperni/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/shaunakperni/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/shaunakperni/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/shaunakperni/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/shaunakperni/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/shaunakperni/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/shaunakperni/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/shaunakperni/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/shaunakperni/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[113], line 43
#      41             average_kappa_without_itself += kappa_matrix_value
#      42             count += 1
# ---> 43     average_kappa__without_own_series[name1] = average_kappa_without_itself / count
#      44     average_kappa_series[name1] = average_kappa / count
#      46 # Calculate the Overall Average Kappa and Peer Average Kappa for each model
#
# ZeroDivisionError: division by zero

# %%
results_per_seed
# Out:
# [{'random_state': 0,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6931034482758621,
#     'precision_cv': 0.6832234432234433,
#     'recall_cv': 0.5423076923076924,
#     'f1_cv': 0.5975885167464113,
#     'accuracy_val': 0.6111111111111112,
#     'precision_val': 0.55,
#     'recall_val': 0.6875,
#     'f1_val': 0.6111111111111112},
#    'Random Forest': {'accuracy_cv': 0.6923645320197045,
#     'precision_cv': 0.6733333333333333,
#     'recall_cv': 0.6217948717948718,
#     'f1_cv': 0.6504933391889913,
#     'accuracy_val': 0.6666666666666666,
#     'precision_val': 0.625,
#     'recall_val': 0.625,
#     'f1_val': 0.625},
#    'Support Vector Machine': {'accuracy_cv': 0.6364532019704433,
#     'precision_cv': 0.7666666666666666,
#     'recall_cv': 0.21538461538461537,
#     'f1_cv': 0.3288888888888889,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.8571428571428571,
#     'recall_val': 0.375,
#     'f1_val': 0.5217391304347826},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.6711822660098521,
#     'precision_cv': 0.6092307692307692,
#     'recall_cv': 0.6384615384615384,
#     'f1_cv': 0.6208857808857808,
#     'accuracy_val': 0.7222222222222222,
#     'precision_val': 0.6875,
#     'recall_val': 0.6875,
#     'f1_val': 0.6875},
#    'Decision Tree': {'accuracy_cv': 0.6926108374384237,
#     'precision_cv': 0.642478354978355,
#     'recall_cv': 0.6871794871794872,
#     'f1_cv': 0.639951452845006,
#     'accuracy_val': 0.7222222222222222,
#     'precision_val': 0.6666666666666666,
#     'recall_val': 0.75,
#     'f1_val': 0.7058823529411765},
#    'Naive Bayes': {'accuracy_cv': 0.6642857142857143,
#     'precision_cv': 0.7045238095238096,
#     'recall_cv': 0.39358974358974363,
#     'f1_cv': 0.49461722488038273,
#     'accuracy_val': 0.6666666666666666,
#     'precision_val': 0.625,
#     'recall_val': 0.625,
#     'f1_val': 0.625}}},
#  {'random_state': 1,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6775862068965517,
#     'precision_cv': 0.6593609022556391,
#     'recall_cv': 0.7638095238095237,
#     'f1_cv': 0.7034308272808567,
#     'accuracy_val': 0.5277777777777778,
#     'precision_val': 0.45,
#     'recall_val': 0.6,
#     'f1_val': 0.5142857142857142},
#    'Random Forest': {'accuracy_cv': 0.6857142857142857,
#     'precision_cv': 0.6969575522516699,
#     'recall_cv': 0.681904761904762,
#     'f1_cv': 0.7042051426923507,
#     'accuracy_val': 0.6388888888888888,
#     'precision_val': 0.55,
#     'recall_val': 0.7333333333333333,
#     'f1_val': 0.6285714285714286},
#    'Support Vector Machine': {'accuracy_cv': 0.6298029556650246,
#     'precision_cv': 0.6674603174603174,
#     'recall_cv': 0.5,
#     'f1_cv': 0.5661720726938119,
#     'accuracy_val': 0.7222222222222222,
#     'precision_val': 0.6923076923076923,
#     'recall_val': 0.6,
#     'f1_val': 0.6428571428571429},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.644088669950739,
#     'precision_cv': 0.6346491228070176,
#     'recall_cv': 0.7238095238095238,
#     'f1_cv': 0.6716604631927213,
#     'accuracy_val': 0.6666666666666666,
#     'precision_val': 0.6,
#     'recall_val': 0.6,
#     'f1_val': 0.6},
#    'Decision Tree': {'accuracy_cv': 0.7549261083743842,
#     'precision_cv': 0.795967365967366,
#     'recall_cv': 0.6961904761904762,
#     'f1_cv': 0.7217745217745218,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.6428571428571429,
#     'recall_val': 0.6,
#     'f1_val': 0.6206896551724138},
#    'Naive Bayes': {'accuracy_cv': 0.6571428571428573,
#     'precision_cv': 0.6666844919786097,
#     'recall_cv': 0.6104761904761904,
#     'f1_cv': 0.6309611248966088,
#     'accuracy_val': 0.5555555555555556,
#     'precision_val': 0.4666666666666667,
#     'recall_val': 0.4666666666666667,
#     'f1_val': 0.4666666666666667}}},
#  {'random_state': 2,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6504926108374384,
#     'precision_cv': 0.6747222222222222,
#     'recall_cv': 0.543956043956044,
#     'f1_cv': 0.5954967061923584,
#     'accuracy_val': 0.8333333333333334,
#     'precision_val': 0.9230769230769231,
#     'recall_val': 0.7058823529411765,
#     'f1_val': 0.8},
#    'Random Forest': {'accuracy_cv': 0.6650246305418719,
#     'precision_cv': 0.6485020242914981,
#     'recall_cv': 0.7087912087912087,
#     'f1_cv': 0.6730015082956259,
#     'accuracy_val': 0.7222222222222222,
#     'precision_val': 0.7692307692307693,
#     'recall_val': 0.5882352941176471,
#     'f1_val': 0.6666666666666666},
#    'Support Vector Machine': {'accuracy_cv': 0.5450738916256157,
#     'precision_cv': 0.65,
#     'recall_cv': 0.14615384615384613,
#     'f1_cv': 0.23058823529411768,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 1.0,
#     'recall_val': 0.35294117647058826,
#     'f1_val': 0.5217391304347826},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.6300492610837438,
#     'precision_cv': 0.5917948717948718,
#     'recall_cv': 0.6494505494505495,
#     'f1_cv': 0.6163003663003663,
#     'accuracy_val': 0.75,
#     'precision_val': 0.7,
#     'recall_val': 0.8235294117647058,
#     'f1_val': 0.7567567567567568},
#    'Decision Tree': {'accuracy_cv': 0.664039408866995,
#     'precision_cv': 0.7280481283422461,
#     'recall_cv': 0.6472527472527472,
#     'f1_cv': 0.6609957817118943,
#     'accuracy_val': 0.7222222222222222,
#     'precision_val': 0.7058823529411765,
#     'recall_val': 0.7058823529411765,
#     'f1_val': 0.7058823529411765},
#    'Naive Bayes': {'accuracy_cv': 0.5869458128078817,
#     'precision_cv': 0.5992673992673992,
#     'recall_cv': 0.3197802197802198,
#     'f1_cv': 0.4029671400724032,
#     'accuracy_val': 0.6666666666666666,
#     'precision_val': 1.0,
#     'recall_val': 0.29411764705882354,
#     'f1_val': 0.45454545454545453}}},
#  {'random_state': 3,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6780788177339901,
#     'precision_cv': 0.6898268398268398,
#     'recall_cv': 0.6021978021978022,
#     'f1_cv': 0.6391714951714952,
#     'accuracy_val': 0.7222222222222222,
#     'precision_val': 0.6153846153846154,
#     'recall_val': 0.6153846153846154,
#     'f1_val': 0.6153846153846154},
#    'Random Forest': {'accuracy_cv': 0.733743842364532,
#     'precision_cv': 0.7589355742296918,
#     'recall_cv': 0.6758241758241758,
#     'f1_cv': 0.6940933977455717,
#     'accuracy_val': 0.8611111111111112,
#     'precision_val': 0.75,
#     'recall_val': 0.9230769230769231,
#     'f1_val': 0.8275862068965517},
#    'Support Vector Machine': {'accuracy_cv': 0.6295566502463055,
#     'precision_cv': 0.7433333333333334,
#     'recall_cv': 0.3505494505494506,
#     'f1_cv': 0.45114269788182837,
#     'accuracy_val': 0.6388888888888888,
#     'precision_val': 0.5,
#     'recall_val': 0.15384615384615385,
#     'f1_val': 0.23529411764705882},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.6435960591133004,
#     'precision_cv': 0.6357894736842105,
#     'recall_cv': 0.6010989010989011,
#     'f1_cv': 0.6083552769070011,
#     'accuracy_val': 0.8055555555555556,
#     'precision_val': 0.7142857142857143,
#     'recall_val': 0.7692307692307693,
#     'f1_val': 0.7407407407407407},
#    'Decision Tree': {'accuracy_cv': 0.7197044334975369,
#     'precision_cv': 0.7169580419580419,
#     'recall_cv': 0.6285714285714286,
#     'f1_cv': 0.6987401512918754,
#     'accuracy_val': 0.7222222222222222,
#     'precision_val': 0.6153846153846154,
#     'recall_val': 0.6153846153846154,
#     'f1_val': 0.6153846153846154},
#    'Naive Bayes': {'accuracy_cv': 0.6012315270935961,
#     'precision_cv': 0.6347435897435898,
#     'recall_cv': 0.3802197802197802,
#     'f1_cv': 0.464771106510237,
#     'accuracy_val': 0.6388888888888888,
#     'precision_val': 0.5,
#     'recall_val': 0.3076923076923077,
#     'f1_val': 0.38095238095238093}}},
#  {'random_state': 4,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6926108374384237,
#     'precision_cv': 0.6942857142857143,
#     'recall_cv': 0.49230769230769234,
#     'f1_cv': 0.5730416951469582,
#     'accuracy_val': 0.5,
#     'precision_val': 0.5384615384615384,
#     'recall_val': 0.3684210526315789,
#     'f1_val': 0.4375},
#    'Random Forest': {'accuracy_cv': 0.720935960591133,
#     'precision_cv': 0.6950882450882452,
#     'recall_cv': 0.6397435897435897,
#     'f1_cv': 0.6918321891685736,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.7222222222222222,
#     'recall_val': 0.6842105263157895,
#     'f1_val': 0.7027027027027027},
#    'Support Vector Machine': {'accuracy_cv': 0.6571428571428573,
#     'precision_cv': 0.8914285714285715,
#     'recall_cv': 0.24743589743589745,
#     'f1_cv': 0.36100658887036596,
#     'accuracy_val': 0.5277777777777778,
#     'precision_val': 0.6666666666666666,
#     'recall_val': 0.21052631578947367,
#     'f1_val': 0.32},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.7551724137931034,
#     'precision_cv': 0.7583333333333334,
#     'recall_cv': 0.6397435897435898,
#     'f1_cv': 0.6897364953886693,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.75,
#     'recall_val': 0.631578947368421,
#     'f1_val': 0.6857142857142857},
#    'Decision Tree': {'accuracy_cv': 0.6854679802955665,
#     'precision_cv': 0.6712503183091418,
#     'recall_cv': 0.641025641025641,
#     'f1_cv': 0.6285823754789273,
#     'accuracy_val': 0.6666666666666666,
#     'precision_val': 0.6842105263157895,
#     'recall_val': 0.6842105263157895,
#     'f1_val': 0.6842105263157895},
#    'Naive Bayes': {'accuracy_cv': 0.6923645320197045,
#     'precision_cv': 0.7412698412698413,
#     'recall_cv': 0.4269230769230769,
#     'f1_cv': 0.5380116959064327,
#     'accuracy_val': 0.4722222222222222,
#     'precision_val': 0.5,
#     'recall_val': 0.21052631578947367,
#     'f1_val': 0.2962962962962963}}},
#  {'random_state': 5,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6716748768472908,
#     'precision_cv': 0.661075036075036,
#     'recall_cv': 0.654945054945055,
#     'f1_cv': 0.6387236612108692,
#     'accuracy_val': 0.5555555555555556,
#     'precision_val': 0.55,
#     'recall_val': 0.6111111111111112,
#     'f1_val': 0.5789473684210527},
#    'Random Forest': {'accuracy_cv': 0.683743842364532,
#     'precision_cv': 0.6857575757575758,
#     'recall_cv': 0.6978021978021978,
#     'f1_cv': 0.6697423266388783,
#     'accuracy_val': 0.7222222222222222,
#     'precision_val': 0.7222222222222222,
#     'recall_val': 0.7222222222222222,
#     'f1_val': 0.7222222222222222},
#    'Support Vector Machine': {'accuracy_cv': 0.5731527093596058,
#     'precision_cv': 0.6533333333333333,
#     'recall_cv': 0.15164835164835164,
#     'f1_cv': 0.24205882352941174,
#     'accuracy_val': 0.6111111111111112,
#     'precision_val': 0.8333333333333334,
#     'recall_val': 0.2777777777777778,
#     'f1_val': 0.4166666666666667},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.6364532019704434,
#     'precision_cv': 0.5990384615384615,
#     'recall_cv': 0.6241758241758241,
#     'f1_cv': 0.6098437960506926,
#     'accuracy_val': 0.5833333333333334,
#     'precision_val': 0.5882352941176471,
#     'recall_val': 0.5555555555555556,
#     'f1_val': 0.5714285714285714},
#    'Decision Tree': {'accuracy_cv': 0.6561576354679802,
#     'precision_cv': 0.6836888111888112,
#     'recall_cv': 0.6373626373626374,
#     'f1_cv': 0.6417299042786299,
#     'accuracy_val': 0.5833333333333334,
#     'precision_val': 0.6,
#     'recall_val': 0.5,
#     'f1_val': 0.5454545454545454},
#    'Naive Bayes': {'accuracy_cv': 0.6283251231527094,
#     'precision_cv': 0.6678571428571428,
#     'recall_cv': 0.378021978021978,
#     'f1_cv': 0.47968253968253977,
#     'accuracy_val': 0.5833333333333334,
#     'precision_val': 0.6363636363636364,
#     'recall_val': 0.3888888888888889,
#     'f1_val': 0.4827586206896552}}},
#  {'random_state': 6,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6849753694581281,
#     'precision_cv': 0.6963672438672438,
#     'recall_cv': 0.612087912087912,
#     'f1_cv': 0.6442678011643529,
#     'accuracy_val': 0.6666666666666666,
#     'precision_val': 0.5882352941176471,
#     'recall_val': 0.6666666666666666,
#     'f1_val': 0.625},
#    'Random Forest': {'accuracy_cv': 0.7475369458128078,
#     'precision_cv': 0.733968253968254,
#     'recall_cv': 0.7472527472527473,
#     'f1_cv': 0.7340897293288839,
#     'accuracy_val': 0.6666666666666666,
#     'precision_val': 0.6,
#     'recall_val': 0.6,
#     'f1_val': 0.6},
#    'Support Vector Machine': {'accuracy_cv': 0.6155172413793103,
#     'precision_cv': 0.6388888888888888,
#     'recall_cv': 0.23846153846153845,
#     'f1_cv': 0.3328282828282828,
#     'accuracy_val': 0.5555555555555556,
#     'precision_val': 0.3333333333333333,
#     'recall_val': 0.06666666666666667,
#     'f1_val': 0.1111111111111111},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.6571428571428573,
#     'precision_cv': 0.6320773524720893,
#     'recall_cv': 0.6868131868131868,
#     'f1_cv': 0.6514022988505748,
#     'accuracy_val': 0.4722222222222222,
#     'precision_val': 0.3333333333333333,
#     'recall_val': 0.26666666666666666,
#     'f1_val': 0.2962962962962963},
#    'Decision Tree': {'accuracy_cv': 0.7130541871921181,
#     'precision_cv': 0.7114234784823019,
#     'recall_cv': 0.6879120879120879,
#     'f1_cv': 0.7030242021846219,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.6666666666666666,
#     'recall_val': 0.5333333333333333,
#     'f1_val': 0.5925925925925926},
#    'Naive Bayes': {'accuracy_cv': 0.6298029556650245,
#     'precision_cv': 0.6883333333333334,
#     'recall_cv': 0.3879120879120879,
#     'f1_cv': 0.48355555555555557,
#     'accuracy_val': 0.6666666666666666,
#     'precision_val': 0.6363636363636364,
#     'recall_val': 0.4666666666666667,
#     'f1_val': 0.5384615384615384}}},
#  {'random_state': 7,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6714285714285714,
#     'precision_cv': 0.6190476190476191,
#     'recall_cv': 0.5705128205128205,
#     'f1_cv': 0.5836174904000991,
#     'accuracy_val': 0.7777777777777778,
#     'precision_val': 0.7,
#     'recall_val': 0.5833333333333334,
#     'f1_val': 0.6363636363636364},
#    'Random Forest': {'accuracy_cv': 0.6642857142857143,
#     'precision_cv': 0.7335497835497835,
#     'recall_cv': 0.573076923076923,
#     'f1_cv': 0.5686830713146502,
#     'accuracy_val': 0.6666666666666666,
#     'precision_val': 0.5,
#     'recall_val': 0.5,
#     'f1_val': 0.5},
#    'Support Vector Machine': {'accuracy_cv': 0.5733990147783251,
#     'precision_cv': 0.5066666666666666,
#     'recall_cv': 0.12564102564102567,
#     'f1_cv': 0.19076923076923075,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.6666666666666666,
#     'recall_val': 0.16666666666666666,
#     'f1_val': 0.26666666666666666},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.664039408866995,
#     'precision_cv': 0.6177289377289377,
#     'recall_cv': 0.5858974358974359,
#     'f1_cv': 0.5978452336713206,
#     'accuracy_val': 0.5277777777777778,
#     'precision_val': 0.3076923076923077,
#     'recall_val': 0.3333333333333333,
#     'f1_val': 0.32},
#    'Decision Tree': {'accuracy_cv': 0.6990147783251232,
#     'precision_cv': 0.7171212121212122,
#     'recall_cv': 0.573076923076923,
#     'f1_cv': 0.547381007739064,
#     'accuracy_val': 0.6111111111111112,
#     'precision_val': 0.4166666666666667,
#     'recall_val': 0.4166666666666667,
#     'f1_val': 0.4166666666666667},
#    'Naive Bayes': {'accuracy_cv': 0.6645320197044334,
#     'precision_cv': 0.6237662337662337,
#     'recall_cv': 0.5551282051282052,
#     'f1_cv': 0.5832206119162641,
#     'accuracy_val': 0.7777777777777778,
#     'precision_val': 0.75,
#     'recall_val': 0.5,
#     'f1_val': 0.6}}},
#  {'random_state': 8,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6357142857142857,
#     'precision_cv': 0.6683150183150184,
#     'recall_cv': 0.5505494505494506,
#     'f1_cv': 0.5892551892551892,
#     'accuracy_val': 0.6388888888888888,
#     'precision_val': 0.6,
#     'recall_val': 0.5625,
#     'f1_val': 0.5806451612903226},
#    'Random Forest': {'accuracy_cv': 0.6581280788177339,
#     'precision_cv': 0.6492673992673993,
#     'recall_cv': 0.6384615384615385,
#     'f1_cv': 0.6557941420010385,
#     'accuracy_val': 0.7777777777777778,
#     'precision_val': 0.7222222222222222,
#     'recall_val': 0.8125,
#     'f1_val': 0.7647058823529411},
#    'Support Vector Machine': {'accuracy_cv': 0.5874384236453202,
#     'precision_cv': 0.7461904761904762,
#     'recall_cv': 0.23186813186813188,
#     'f1_cv': 0.346218487394958,
#     'accuracy_val': 0.5833333333333334,
#     'precision_val': 0.5555555555555556,
#     'recall_val': 0.3125,
#     'f1_val': 0.4},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.6083743842364532,
#     'precision_cv': 0.5806268568033274,
#     'recall_cv': 0.6516483516483517,
#     'f1_cv': 0.6101513056835637,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.6470588235294118,
#     'recall_val': 0.6875,
#     'f1_val': 0.6666666666666666},
#    'Decision Tree': {'accuracy_cv': 0.6793103448275862,
#     'precision_cv': 0.6911888111888111,
#     'recall_cv': 0.6384615384615385,
#     'f1_cv': 0.6380952380952382,
#     'accuracy_val': 0.7222222222222222,
#     'precision_val': 0.7142857142857143,
#     'recall_val': 0.625,
#     'f1_val': 0.6666666666666666},
#    'Naive Bayes': {'accuracy_cv': 0.5943349753694581,
#     'precision_cv': 0.6813131313131313,
#     'recall_cv': 0.378021978021978,
#     'f1_cv': 0.4718928414580589,
#     'accuracy_val': 0.5833333333333334,
#     'precision_val': 0.5454545454545454,
#     'recall_val': 0.375,
#     'f1_val': 0.4444444444444444}}},
#  {'random_state': 9,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6568965517241379,
#     'precision_cv': 0.6610805860805861,
#     'recall_cv': 0.5333333333333334,
#     'f1_cv': 0.5542682576311273,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.7857142857142857,
#     'recall_val': 0.5789473684210527,
#     'f1_val': 0.6666666666666666},
#    'Random Forest': {'accuracy_cv': 0.7480295566502464,
#     'precision_cv': 0.7572727272727272,
#     'recall_cv': 0.6833333333333333,
#     'f1_cv': 0.6644033613445378,
#     'accuracy_val': 0.5833333333333334,
#     'precision_val': 0.625,
#     'recall_val': 0.5263157894736842,
#     'f1_val': 0.5714285714285714},
#    'Support Vector Machine': {'accuracy_cv': 0.5869458128078818,
#     'precision_cv': 0.7266666666666667,
#     'recall_cv': 0.13974358974358977,
#     'f1_cv': 0.22412698412698412,
#     'accuracy_val': 0.5555555555555556,
#     'precision_val': 0.8,
#     'recall_val': 0.21052631578947367,
#     'f1_val': 0.3333333333333333},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.7339901477832512,
#     'precision_cv': 0.7134594507659523,
#     'recall_cv': 0.714102564102564,
#     'f1_cv': 0.6967631578947368,
#     'accuracy_val': 0.6111111111111112,
#     'precision_val': 0.6470588235294118,
#     'recall_val': 0.5789473684210527,
#     'f1_val': 0.6111111111111112},
#    'Decision Tree': {'accuracy_cv': 0.6852216748768473,
#     'precision_cv': 0.6930344165638284,
#     'recall_cv': 0.6230769230769231,
#     'f1_cv': 0.6487765006385696,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.7222222222222222,
#     'recall_val': 0.6842105263157895,
#     'f1_val': 0.7027027027027027},
#    'Naive Bayes': {'accuracy_cv': 0.6421182266009853,
#     'precision_cv': 0.7008403361344537,
#     'recall_cv': 0.40512820512820513,
#     'f1_cv': 0.46872549019607845,
#     'accuracy_val': 0.6388888888888888,
#     'precision_val': 0.875,
#     'recall_val': 0.3684210526315789,
#     'f1_val': 0.5185185185185185}}},
#  {'random_state': 10,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6300492610837438,
#     'precision_cv': 0.6313492063492063,
#     'recall_cv': 0.6571428571428571,
#     'f1_cv': 0.6320924764890282,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.6666666666666666,
#     'recall_val': 0.7777777777777778,
#     'f1_val': 0.717948717948718},
#    'Random Forest': {'accuracy_cv': 0.714039408866995,
#     'precision_cv': 0.7151980630308804,
#     'recall_cv': 0.7123809523809524,
#     'f1_cv': 0.7131468531468531,
#     'accuracy_val': 0.7777777777777778,
#     'precision_val': 0.8125,
#     'recall_val': 0.7222222222222222,
#     'f1_val': 0.7647058823529411},
#    'Support Vector Machine': {'accuracy_cv': 0.6431034482758621,
#     'precision_cv': 0.7366411366411365,
#     'recall_cv': 0.4638095238095238,
#     'f1_cv': 0.5607800894757416,
#     'accuracy_val': 0.6666666666666666,
#     'precision_val': 0.8,
#     'recall_val': 0.4444444444444444,
#     'f1_val': 0.5714285714285714},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.6719211822660098,
#     'precision_cv': 0.7063203463203462,
#     'recall_cv': 0.6171428571428571,
#     'f1_cv': 0.6551471516988758,
#     'accuracy_val': 0.6111111111111112,
#     'precision_val': 0.75,
#     'recall_val': 0.3333333333333333,
#     'f1_val': 0.46153846153846156},
#    'Decision Tree': {'accuracy_cv': 0.7071428571428571,
#     'precision_cv': 0.7616450216450217,
#     'recall_cv': 0.6857142857142857,
#     'f1_cv': 0.7101029801841161,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.7692307692307693,
#     'recall_val': 0.5555555555555556,
#     'f1_val': 0.6451612903225806},
#    'Naive Bayes': {'accuracy_cv': 0.5948275862068966,
#     'precision_cv': 0.626984126984127,
#     'recall_cv': 0.5333333333333333,
#     'f1_cv': 0.5645502645502646,
#     'accuracy_val': 0.6666666666666666,
#     'precision_val': 0.6875,
#     'recall_val': 0.6111111111111112,
#     'f1_val': 0.6470588235294118}}},
#  {'random_state': 11,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6849753694581281,
#     'precision_cv': 0.6917443667443667,
#     'recall_cv': 0.5538461538461538,
#     'f1_cv': 0.610972360972361,
#     'accuracy_val': 0.4722222222222222,
#     'precision_val': 0.4166666666666667,
#     'recall_val': 0.29411764705882354,
#     'f1_val': 0.3448275862068966},
#    'Random Forest': {'accuracy_cv': 0.7066502463054187,
#     'precision_cv': 0.6919047619047619,
#     'recall_cv': 0.6,
#     'f1_cv': 0.6290863918690006,
#     'accuracy_val': 0.8333333333333334,
#     'precision_val': 0.8235294117647058,
#     'recall_val': 0.8235294117647058,
#     'f1_val': 0.8235294117647058},
#    'Support Vector Machine': {'accuracy_cv': 0.6224137931034484,
#     'precision_cv': 0.7728571428571429,
#     'recall_cv': 0.2615384615384616,
#     'f1_cv': 0.3794771241830065,
#     'accuracy_val': 0.5277777777777778,
#     'precision_val': 0.5,
#     'recall_val': 0.17647058823529413,
#     'f1_val': 0.2608695652173913},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.6288177339901477,
#     'precision_cv': 0.5983216783216784,
#     'recall_cv': 0.5538461538461539,
#     'f1_cv': 0.5735785953177258,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.7142857142857143,
#     'recall_val': 0.5882352941176471,
#     'f1_val': 0.6451612903225806},
#    'Decision Tree': {'accuracy_cv': 0.7209359605911331,
#     'precision_cv': 0.6911796536796537,
#     'recall_cv': 0.5846153846153845,
#     'f1_cv': 0.6549622331691297,
#     'accuracy_val': 0.8611111111111112,
#     'precision_val': 0.8333333333333334,
#     'recall_val': 0.8823529411764706,
#     'f1_val': 0.8571428571428571},
#    'Naive Bayes': {'accuracy_cv': 0.635960591133005,
#     'precision_cv': 0.6916666666666667,
#     'recall_cv': 0.3692307692307692,
#     'f1_cv': 0.4734134802246257,
#     'accuracy_val': 0.5555555555555556,
#     'precision_val': 0.5454545454545454,
#     'recall_val': 0.35294117647058826,
#     'f1_val': 0.42857142857142855}}},
#  {'random_state': 12,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6583743842364532,
#     'precision_cv': 0.6506493506493507,
#     'recall_cv': 0.5912087912087912,
#     'f1_cv': 0.6160455486542443,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.6363636363636364,
#     'recall_val': 0.8235294117647058,
#     'f1_val': 0.717948717948718},
#    'Random Forest': {'accuracy_cv': 0.7352216748768472,
#     'precision_cv': 0.7336764705882353,
#     'recall_cv': 0.6648351648351648,
#     'f1_cv': 0.7051201671891326,
#     'accuracy_val': 0.6388888888888888,
#     'precision_val': 0.6,
#     'recall_val': 0.7058823529411765,
#     'f1_val': 0.6486486486486487},
#    'Support Vector Machine': {'accuracy_cv': 0.6152709359605912,
#     'precision_cv': 0.7761904761904762,
#     'recall_cv': 0.24065934065934064,
#     'f1_cv': 0.3556553147574819,
#     'accuracy_val': 0.5555555555555556,
#     'precision_val': 0.6,
#     'recall_val': 0.17647058823529413,
#     'f1_val': 0.2727272727272727},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.6019704433497537,
#     'precision_cv': 0.5748102877514641,
#     'recall_cv': 0.5912087912087911,
#     'f1_cv': 0.5801781874039937,
#     'accuracy_val': 0.6388888888888888,
#     'precision_val': 0.6111111111111112,
#     'recall_val': 0.6470588235294118,
#     'f1_val': 0.6285714285714286},
#    'Decision Tree': {'accuracy_cv': 0.6928571428571428,
#     'precision_cv': 0.6885997988939165,
#     'recall_cv': 0.6197802197802198,
#     'f1_cv': 0.6635111917725348,
#     'accuracy_val': 0.6111111111111112,
#     'precision_val': 0.5789473684210527,
#     'recall_val': 0.6470588235294118,
#     'f1_val': 0.6111111111111112},
#    'Naive Bayes': {'accuracy_cv': 0.6157635467980296,
#     'precision_cv': 0.6444444444444445,
#     'recall_cv': 0.378021978021978,
#     'f1_cv': 0.47525691699604744,
#     'accuracy_val': 0.5833333333333334,
#     'precision_val': 0.5714285714285714,
#     'recall_val': 0.47058823529411764,
#     'f1_val': 0.5161290322580645}}},
#  {'random_state': 13,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6714285714285715,
#     'precision_cv': 0.6492965367965368,
#     'recall_cv': 0.6384615384615385,
#     'f1_cv': 0.640286079182631,
#     'accuracy_val': 0.4722222222222222,
#     'precision_val': 0.4444444444444444,
#     'recall_val': 0.47058823529411764,
#     'f1_val': 0.45714285714285713},
#    'Random Forest': {'accuracy_cv': 0.7421182266009853,
#     'precision_cv': 0.763916083916084,
#     'recall_cv': 0.7285714285714285,
#     'f1_cv': 0.7451428571428571,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.6363636363636364,
#     'recall_val': 0.8235294117647058,
#     'f1_val': 0.717948717948718},
#    'Support Vector Machine': {'accuracy_cv': 0.6216748768472906,
#     'precision_cv': 0.6799999999999999,
#     'recall_cv': 0.3340659340659341,
#     'f1_cv': 0.44406166932482727,
#     'accuracy_val': 0.5833333333333334,
#     'precision_val': 0.625,
#     'recall_val': 0.29411764705882354,
#     'f1_val': 0.4},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.655911330049261,
#     'precision_cv': 0.6322077922077922,
#     'recall_cv': 0.6208791208791209,
#     'f1_cv': 0.6214327122153209,
#     'accuracy_val': 0.6388888888888888,
#     'precision_val': 0.6111111111111112,
#     'recall_val': 0.6470588235294118,
#     'f1_val': 0.6285714285714286},
#    'Decision Tree': {'accuracy_cv': 0.776847290640394,
#     'precision_cv': 0.7977156177156177,
#     'recall_cv': 0.7571428571428571,
#     'f1_cv': 0.7228819875776398,
#     'accuracy_val': 0.6666666666666666,
#     'precision_val': 0.6086956521739131,
#     'recall_val': 0.8235294117647058,
#     'f1_val': 0.7},
#    'Naive Bayes': {'accuracy_cv': 0.6642857142857143,
#     'precision_cv': 0.6663403263403262,
#     'recall_cv': 0.5472527472527473,
#     'f1_cv': 0.597881828316611,
#     'accuracy_val': 0.5,
#     'precision_val': 0.46153846153846156,
#     'recall_val': 0.35294117647058826,
#     'f1_val': 0.4}}},
#  {'random_state': 14,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6788177339901478,
#     'precision_cv': 0.6796428571428572,
#     'recall_cv': 0.6714285714285714,
#     'f1_cv': 0.6704761904761904,
#     'accuracy_val': 0.6111111111111112,
#     'precision_val': 0.4166666666666667,
#     'recall_val': 0.4166666666666667,
#     'f1_val': 0.4166666666666667},
#    'Random Forest': {'accuracy_cv': 0.643103448275862,
#     'precision_cv': 0.654251012145749,
#     'recall_cv': 0.6714285714285715,
#     'f1_cv': 0.6543616557734204,
#     'accuracy_val': 0.5833333333333334,
#     'precision_val': 0.4,
#     'recall_val': 0.5,
#     'f1_val': 0.4444444444444444},
#    'Support Vector Machine': {'accuracy_cv': 0.623152709359606,
#     'precision_cv': 0.7178571428571427,
#     'recall_cv': 0.3714285714285714,
#     'f1_cv': 0.47264656911715736,
#     'accuracy_val': 0.6666666666666666,
#     'precision_val': 0.5,
#     'recall_val': 0.25,
#     'f1_val': 0.3333333333333333},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.6,
#     'precision_cv': 0.6011517893870835,
#     'recall_cv': 0.5857142857142856,
#     'f1_cv': 0.5876798088410992,
#     'accuracy_val': 0.6388888888888888,
#     'precision_val': 0.47058823529411764,
#     'recall_val': 0.6666666666666666,
#     'f1_val': 0.5517241379310345},
#    'Decision Tree': {'accuracy_cv': 0.608128078817734,
#     'precision_cv': 0.6174509803921568,
#     'recall_cv': 0.6142857142857142,
#     'f1_cv': 0.6180094658553077,
#     'accuracy_val': 0.5555555555555556,
#     'precision_val': 0.375,
#     'recall_val': 0.5,
#     'f1_val': 0.42857142857142855},
#    'Naive Bayes': {'accuracy_cv': 0.6729064039408866,
#     'precision_cv': 0.7258547008547008,
#     'recall_cv': 0.5142857142857142,
#     'f1_cv': 0.5889767237593324,
#     'accuracy_val': 0.6111111111111112,
#     'precision_val': 0.25,
#     'recall_val': 0.08333333333333333,
#     'f1_val': 0.125}}},
#  {'random_state': 15,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6793103448275863,
#     'precision_cv': 0.6371428571428572,
#     'recall_cv': 0.4712121212121212,
#     'f1_cv': 0.5361403508771929,
#     'accuracy_val': 0.5,
#     'precision_val': 0.6363636363636364,
#     'recall_val': 0.3333333333333333,
#     'f1_val': 0.4375},
#    'Random Forest': {'accuracy_cv': 0.7561576354679803,
#     'precision_cv': 0.7298501498501497,
#     'recall_cv': 0.6772727272727274,
#     'f1_cv': 0.6764308597580909,
#     'accuracy_val': 0.7222222222222222,
#     'precision_val': 0.8666666666666667,
#     'recall_val': 0.6190476190476191,
#     'f1_val': 0.7222222222222222},
#    'Support Vector Machine': {'accuracy_cv': 0.6229064039408867,
#     'precision_cv': 0.6833333333333333,
#     'recall_cv': 0.13939393939393938,
#     'f1_cv': 0.22380952380952382,
#     'accuracy_val': 0.4444444444444444,
#     'precision_val': 0.6,
#     'recall_val': 0.14285714285714285,
#     'f1_val': 0.23076923076923078},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.7,
#     'precision_cv': 0.6555844155844156,
#     'recall_cv': 0.553030303030303,
#     'f1_cv': 0.5964866051822574,
#     'accuracy_val': 0.5555555555555556,
#     'precision_val': 0.6923076923076923,
#     'recall_val': 0.42857142857142855,
#     'f1_val': 0.5294117647058824},
#    'Decision Tree': {'accuracy_cv': 0.6726600985221675,
#     'precision_cv': 0.6419191919191919,
#     'recall_cv': 0.6090909090909091,
#     'f1_cv': 0.6425477131564088,
#     'accuracy_val': 0.6388888888888888,
#     'precision_val': 0.8333333333333334,
#     'recall_val': 0.47619047619047616,
#     'f1_val': 0.6060606060606061},
#    'Naive Bayes': {'accuracy_cv': 0.6443349753694582,
#     'precision_cv': 0.6,
#     'recall_cv': 0.35,
#     'f1_cv': 0.4345471521942111,
#     'accuracy_val': 0.4722222222222222,
#     'precision_val': 0.625,
#     'recall_val': 0.23809523809523808,
#     'f1_val': 0.3448275862068966}}},
#  {'random_state': 16,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.684975369458128,
#     'precision_cv': 0.6955025366790073,
#     'recall_cv': 0.6,
#     'f1_cv': 0.6270580296896087,
#     'accuracy_val': 0.5,
#     'precision_val': 0.3333333333333333,
#     'recall_val': 0.2857142857142857,
#     'f1_val': 0.3076923076923077},
#    'Random Forest': {'accuracy_cv': 0.7342364532019705,
#     'precision_cv': 0.7453679653679653,
#     'recall_cv': 0.7076923076923077,
#     'f1_cv': 0.7257230273752012,
#     'accuracy_val': 0.5555555555555556,
#     'precision_val': 0.4,
#     'recall_val': 0.2857142857142857,
#     'f1_val': 0.3333333333333333},
#    'Support Vector Machine': {'accuracy_cv': 0.6706896551724137,
#     'precision_cv': 0.95,
#     'recall_cv': 0.30769230769230776,
#     'f1_cv': 0.4439348370927318,
#     'accuracy_val': 0.5277777777777778,
#     'precision_val': 0.2,
#     'recall_val': 0.07142857142857142,
#     'f1_val': 0.10526315789473684},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.7071428571428572,
#     'precision_cv': 0.72252331002331,
#     'recall_cv': 0.6307692307692307,
#     'f1_cv': 0.6576062171343479,
#     'accuracy_val': 0.5555555555555556,
#     'precision_val': 0.4166666666666667,
#     'recall_val': 0.35714285714285715,
#     'f1_val': 0.38461538461538464},
#    'Decision Tree': {'accuracy_cv': 0.7763546798029556,
#     'precision_cv': 0.7465667665667667,
#     'recall_cv': 0.7538461538461538,
#     'f1_cv': 0.7618437118437118,
#     'accuracy_val': 0.6111111111111112,
#     'precision_val': 0.5,
#     'recall_val': 0.35714285714285715,
#     'f1_val': 0.4166666666666667},
#    'Naive Bayes': {'accuracy_cv': 0.6566502463054188,
#     'precision_cv': 0.6903174603174603,
#     'recall_cv': 0.4153846153846154,
#     'f1_cv': 0.5150937950937952,
#     'accuracy_val': 0.5,
#     'precision_val': 0.25,
#     'recall_val': 0.14285714285714285,
#     'f1_val': 0.18181818181818182}}},
#  {'random_state': 17,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6086206896551725,
#     'precision_cv': 0.6235531135531136,
#     'recall_cv': 0.6095238095238095,
#     'f1_cv': 0.5994088669950739,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.5714285714285714,
#     'recall_val': 0.8571428571428571,
#     'f1_val': 0.6857142857142857},
#    'Random Forest': {'accuracy_cv': 0.7061576354679803,
#     'precision_cv': 0.7262626262626263,
#     'recall_cv': 0.7361904761904762,
#     'f1_cv': 0.6808932461873638,
#     'accuracy_val': 0.75,
#     'precision_val': 0.6190476190476191,
#     'recall_val': 0.9285714285714286,
#     'f1_val': 0.7428571428571429},
#    'Support Vector Machine': {'accuracy_cv': 0.5948275862068966,
#     'precision_cv': 0.6121794871794871,
#     'recall_cv': 0.48571428571428577,
#     'f1_cv': 0.5357239057239057,
#     'accuracy_val': 0.75,
#     'precision_val': 0.7272727272727273,
#     'recall_val': 0.5714285714285714,
#     'f1_val': 0.64},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.6157635467980296,
#     'precision_cv': 0.6332167832167832,
#     'recall_cv': 0.5828571428571429,
#     'f1_cv': 0.5991957671957672,
#     'accuracy_val': 0.6388888888888888,
#     'precision_val': 0.5294117647058824,
#     'recall_val': 0.6428571428571429,
#     'f1_val': 0.5806451612903226},
#    'Decision Tree': {'accuracy_cv': 0.6573891625615763,
#     'precision_cv': 0.7113562091503267,
#     'recall_cv': 0.7085714285714285,
#     'f1_cv': 0.6923892723678219,
#     'accuracy_val': 0.8055555555555556,
#     'precision_val': 0.7058823529411765,
#     'recall_val': 0.8571428571428571,
#     'f1_val': 0.7741935483870968},
#    'Naive Bayes': {'accuracy_cv': 0.6229064039408867,
#     'precision_cv': 0.6385026737967914,
#     'recall_cv': 0.5428571428571428,
#     'f1_cv': 0.5721561264822135,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.6153846153846154,
#     'recall_val': 0.5714285714285714,
#     'f1_val': 0.5925925925925926}}},
#  {'random_state': 18,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6433497536945814,
#     'precision_cv': 0.6143290043290044,
#     'recall_cv': 0.5474358974358975,
#     'f1_cv': 0.5769538866930171,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.7142857142857143,
#     'recall_val': 0.5882352941176471,
#     'f1_val': 0.6451612903225806},
#    'Random Forest': {'accuracy_cv': 0.629064039408867,
#     'precision_cv': 0.6141666666666667,
#     'recall_cv': 0.6217948717948718,
#     'f1_cv': 0.6170037161870192,
#     'accuracy_val': 0.7222222222222222,
#     'precision_val': 0.7333333333333333,
#     'recall_val': 0.6470588235294118,
#     'f1_val': 0.6875},
#    'Support Vector Machine': {'accuracy_cv': 0.6152709359605912,
#     'precision_cv': 0.78,
#     'recall_cv': 0.21794871794871798,
#     'f1_cv': 0.3318504594820384,
#     'accuracy_val': 0.6388888888888888,
#     'precision_val': 0.8333333333333334,
#     'recall_val': 0.29411764705882354,
#     'f1_val': 0.43478260869565216},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.5657635467980295,
#     'precision_cv': 0.5476190476190477,
#     'recall_cv': 0.48461538461538467,
#     'f1_cv': 0.4987881581348006,
#     'accuracy_val': 0.7777777777777778,
#     'precision_val': 0.8,
#     'recall_val': 0.7058823529411765,
#     'f1_val': 0.75},
#    'Decision Tree': {'accuracy_cv': 0.6160098522167489,
#     'precision_cv': 0.5707936507936509,
#     'recall_cv': 0.5935897435897436,
#     'f1_cv': 0.5569783860106441,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.7142857142857143,
#     'recall_val': 0.5882352941176471,
#     'f1_val': 0.6451612903225806},
#    'Naive Bayes': {'accuracy_cv': 0.6352216748768473,
#     'precision_cv': 0.6333333333333334,
#     'recall_cv': 0.4051282051282052,
#     'f1_cv': 0.48321383168065085,
#     'accuracy_val': 0.6388888888888888,
#     'precision_val': 0.6666666666666666,
#     'recall_val': 0.47058823529411764,
#     'f1_val': 0.5517241379310345}}},
#  {'random_state': 19,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.7189655172413794,
#     'precision_cv': 0.7593434343434343,
#     'recall_cv': 0.5641025641025641,
#     'f1_cv': 0.6433333333333333,
#     'accuracy_val': 0.4722222222222222,
#     'precision_val': 0.46153846153846156,
#     'recall_val': 0.3333333333333333,
#     'f1_val': 0.3870967741935484},
#    'Random Forest': {'accuracy_cv': 0.7268472906403941,
#     'precision_cv': 0.658888888888889,
#     'recall_cv': 0.6782051282051282,
#     'f1_cv': 0.6587542087542088,
#     'accuracy_val': 0.7222222222222222,
#     'precision_val': 0.7857142857142857,
#     'recall_val': 0.6111111111111112,
#     'f1_val': 0.6875},
#    'Support Vector Machine': {'accuracy_cv': 0.6150246305418718,
#     'precision_cv': 0.7133333333333333,
#     'recall_cv': 0.20897435897435898,
#     'f1_cv': 0.32189542483660133,
#     'accuracy_val': 0.5,
#     'precision_val': 0.5,
#     'recall_val': 0.1111111111111111,
#     'f1_val': 0.18181818181818182},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.6078817733990147,
#     'precision_cv': 0.5478210678210678,
#     'recall_cv': 0.5653846153846154,
#     'f1_cv': 0.5506089723481028,
#     'accuracy_val': 0.5277777777777778,
#     'precision_val': 0.5333333333333333,
#     'recall_val': 0.4444444444444444,
#     'f1_val': 0.48484848484848486},
#    'Decision Tree': {'accuracy_cv': 0.6995073891625616,
#     'precision_cv': 0.6394047619047618,
#     'recall_cv': 0.6448717948717949,
#     'f1_cv': 0.6437441179510145,
#     'accuracy_val': 0.75,
#     'precision_val': 0.8461538461538461,
#     'recall_val': 0.6111111111111112,
#     'f1_val': 0.7096774193548387},
#    'Naive Bayes': {'accuracy_cv': 0.6564039408866995,
#     'precision_cv': 0.7228571428571429,
#     'recall_cv': 0.4025641025641026,
#     'f1_cv': 0.5099915564311849,
#     'accuracy_val': 0.4722222222222222,
#     'precision_val': 0.4444444444444444,
#     'recall_val': 0.2222222222222222,
#     'f1_val': 0.2962962962962963}}},
#  {'random_state': 20,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.5879310344827587,
#     'precision_cv': 0.6152346999405823,
#     'recall_cv': 0.48571428571428565,
#     'f1_cv': 0.5375642823749416,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.7272727272727273,
#     'recall_val': 0.5,
#     'f1_val': 0.5925925925925926},
#    'Random Forest': {'accuracy_cv': 0.7204433497536945,
#     'precision_cv': 0.7131598793363499,
#     'recall_cv': 0.6615384615384615,
#     'f1_cv': 0.7080128205128204,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.6470588235294118,
#     'recall_val': 0.6875,
#     'f1_val': 0.6666666666666666},
#    'Support Vector Machine': {'accuracy_cv': 0.6014778325123153,
#     'precision_cv': 0.780952380952381,
#     'recall_cv': 0.25054945054945055,
#     'f1_cv': 0.36044228217602825,
#     'accuracy_val': 0.5833333333333334,
#     'precision_val': 0.6666666666666666,
#     'recall_val': 0.125,
#     'f1_val': 0.21052631578947367},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.6847290640394089,
#     'precision_cv': 0.6736263736263737,
#     'recall_cv': 0.6615384615384615,
#     'f1_cv': 0.6666666666666666,
#     'accuracy_val': 0.6388888888888888,
#     'precision_val': 0.6,
#     'recall_val': 0.5625,
#     'f1_val': 0.5806451612903226},
#    'Decision Tree': {'accuracy_cv': 0.684975369458128,
#     'precision_cv': 0.6832579185520362,
#     'recall_cv': 0.6582417582417582,
#     'f1_cv': 0.6961151005505843,
#     'accuracy_val': 0.7777777777777778,
#     'precision_val': 0.7,
#     'recall_val': 0.875,
#     'f1_val': 0.7777777777777778},
#    'Naive Bayes': {'accuracy_cv': 0.6285714285714287,
#     'precision_cv': 0.66,
#     'recall_cv': 0.36483516483516476,
#     'f1_cv': 0.4558718062123635,
#     'accuracy_val': 0.6111111111111112,
#     'precision_val': 0.625,
#     'recall_val': 0.3125,
#     'f1_val': 0.4166666666666667}}},
#  {'random_state': 21,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.593103448275862,
#     'precision_cv': 0.5767282554047259,
#     'recall_cv': 0.5895238095238095,
#     'f1_cv': 0.5775699963638252,
#     'accuracy_val': 0.7222222222222222,
#     'precision_val': 0.5882352941176471,
#     'recall_val': 0.7692307692307693,
#     'f1_val': 0.6666666666666666},
#    'Random Forest': {'accuracy_cv': 0.6913793103448276,
#     'precision_cv': 0.6938273491214667,
#     'recall_cv': 0.660952380952381,
#     'f1_cv': 0.6642900088417331,
#     'accuracy_val': 0.8333333333333334,
#     'precision_val': 0.7692307692307693,
#     'recall_val': 0.7692307692307693,
#     'f1_val': 0.7692307692307693},
#    'Support Vector Machine': {'accuracy_cv': 0.6073891625615764,
#     'precision_cv': 0.6905128205128205,
#     'recall_cv': 0.3476190476190476,
#     'f1_cv': 0.44216477021430584,
#     'accuracy_val': 0.7777777777777778,
#     'precision_val': 0.7272727272727273,
#     'recall_val': 0.6153846153846154,
#     'f1_val': 0.6666666666666666},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.644088669950739,
#     'precision_cv': 0.6602897102897103,
#     'recall_cv': 0.5914285714285714,
#     'f1_cv': 0.6228746017711535,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.5625,
#     'recall_val': 0.6923076923076923,
#     'f1_val': 0.6206896551724138},
#    'Decision Tree': {'accuracy_cv': 0.7401477832512315,
#     'precision_cv': 0.7427838827838829,
#     'recall_cv': 0.718095238095238,
#     'f1_cv': 0.7080066804204734,
#     'accuracy_val': 0.7777777777777778,
#     'precision_val': 0.6666666666666666,
#     'recall_val': 0.7692307692307693,
#     'f1_val': 0.7142857142857143},
#    'Naive Bayes': {'accuracy_cv': 0.6012315270935961,
#     'precision_cv': 0.6678571428571429,
#     'recall_cv': 0.4333333333333333,
#     'f1_cv': 0.5084808796184008,
#     'accuracy_val': 0.8055555555555556,
#     'precision_val': 0.8,
#     'recall_val': 0.6153846153846154,
#     'f1_val': 0.6956521739130435}}},
#  {'random_state': 22,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6364532019704434,
#     'precision_cv': 0.5998949579831933,
#     'recall_cv': 0.6626373626373626,
#     'f1_cv': 0.6246755654430849,
#     'accuracy_val': 0.6111111111111112,
#     'precision_val': 0.5454545454545454,
#     'recall_val': 0.4,
#     'f1_val': 0.46153846153846156},
#    'Random Forest': {'accuracy_cv': 0.7051724137931034,
#     'precision_cv': 0.7247552447552448,
#     'recall_cv': 0.6274725274725275,
#     'f1_cv': 0.6549559136515659,
#     'accuracy_val': 0.6666666666666666,
#     'precision_val': 0.5882352941176471,
#     'recall_val': 0.6666666666666666,
#     'f1_val': 0.625},
#    'Support Vector Machine': {'accuracy_cv': 0.587192118226601,
#     'precision_cv': 0.775,
#     'recall_cv': 0.22087912087912084,
#     'f1_cv': 0.30766233766233764,
#     'accuracy_val': 0.6111111111111112,
#     'precision_val': 0.6666666666666666,
#     'recall_val': 0.13333333333333333,
#     'f1_val': 0.2222222222222222},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.7334975369458128,
#     'precision_cv': 0.7503052503052503,
#     'recall_cv': 0.6758241758241758,
#     'f1_cv': 0.7059599016120754,
#     'accuracy_val': 0.5277777777777778,
#     'precision_val': 0.45,
#     'recall_val': 0.6,
#     'f1_val': 0.5142857142857142},
#    'Decision Tree': {'accuracy_cv': 0.6706896551724137,
#     'precision_cv': 0.6417948717948718,
#     'recall_cv': 0.6142857142857143,
#     'f1_cv': 0.6363190904547726,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.625,
#     'recall_val': 0.6666666666666666,
#     'f1_val': 0.6451612903225806},
#    'Naive Bayes': {'accuracy_cv': 0.6017241379310344,
#     'precision_cv': 0.6133333333333333,
#     'recall_cv': 0.3989010989010989,
#     'f1_cv': 0.4745498462889767,
#     'accuracy_val': 0.6388888888888888,
#     'precision_val': 0.75,
#     'recall_val': 0.2,
#     'f1_val': 0.3157894736842105}}},
#  {'random_state': 23,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6216748768472906,
#     'precision_cv': 0.6376767676767676,
#     'recall_cv': 0.6409523809523809,
#     'f1_cv': 0.6305481874447392,
#     'accuracy_val': 0.7222222222222222,
#     'precision_val': 0.5555555555555556,
#     'recall_val': 0.45454545454545453,
#     'f1_val': 0.5},
#    'Random Forest': {'accuracy_cv': 0.6583743842364532,
#     'precision_cv': 0.6477910462430586,
#     'recall_cv': 0.6723809523809524,
#     'f1_cv': 0.6400238948626045,
#     'accuracy_val': 0.6666666666666666,
#     'precision_val': 0.47058823529411764,
#     'recall_val': 0.7272727272727273,
#     'f1_val': 0.5714285714285714},
#    'Support Vector Machine': {'accuracy_cv': 0.6224137931034482,
#     'precision_cv': 0.721965811965812,
#     'recall_cv': 0.4333333333333333,
#     'f1_cv': 0.5293485580442102,
#     'accuracy_val': 0.7777777777777778,
#     'precision_val': 1.0,
#     'recall_val': 0.2727272727272727,
#     'f1_val': 0.42857142857142855},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.6224137931034484,
#     'precision_cv': 0.6215643274853802,
#     'recall_cv': 0.638095238095238,
#     'f1_cv': 0.6184927062612485,
#     'accuracy_val': 0.6388888888888888,
#     'precision_val': 0.4444444444444444,
#     'recall_val': 0.7272727272727273,
#     'f1_val': 0.5517241379310345},
#    'Decision Tree': {'accuracy_cv': 0.6428571428571429,
#     'precision_cv': 0.635483193277311,
#     'recall_cv': 0.6266666666666666,
#     'f1_cv': 0.6271046135918216,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.5,
#     'recall_val': 0.7272727272727273,
#     'f1_val': 0.5925925925925926},
#    'Naive Bayes': {'accuracy_cv': 0.6295566502463054,
#     'precision_cv': 0.7592857142857142,
#     'recall_cv': 0.418095238095238,
#     'f1_cv': 0.5206016714025867,
#     'accuracy_val': 0.7222222222222222,
#     'precision_val': 0.6,
#     'recall_val': 0.2727272727272727,
#     'f1_val': 0.375}}},
#  {'random_state': 24,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6431034482758621,
#     'precision_cv': 0.6364302364302363,
#     'recall_cv': 0.49230769230769234,
#     'f1_cv': 0.5424156545209178,
#     'accuracy_val': 0.75,
#     'precision_val': 0.875,
#     'recall_val': 0.4666666666666667,
#     'f1_val': 0.6086956521739131},
#    'Random Forest': {'accuracy_cv': 0.6711822660098522,
#     'precision_cv': 0.6502886002886002,
#     'recall_cv': 0.6307692307692307,
#     'f1_cv': 0.6315646952393096,
#     'accuracy_val': 0.8611111111111112,
#     'precision_val': 0.9166666666666666,
#     'recall_val': 0.7333333333333333,
#     'f1_val': 0.8148148148148148},
#    'Support Vector Machine': {'accuracy_cv': 0.6088669950738917,
#     'precision_cv': 0.6,
#     'recall_cv': 0.23076923076923078,
#     'f1_cv': 0.3306501547987616,
#     'accuracy_val': 0.6666666666666666,
#     'precision_val': 1.0,
#     'recall_val': 0.2,
#     'f1_val': 0.3333333333333333},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.6433497536945813,
#     'precision_cv': 0.6252525252525253,
#     'recall_cv': 0.5692307692307692,
#     'f1_cv': 0.5848878648233486,
#     'accuracy_val': 0.8888888888888888,
#     'precision_val': 0.9230769230769231,
#     'recall_val': 0.8,
#     'f1_val': 0.8571428571428571},
#    'Decision Tree': {'accuracy_cv': 0.6711822660098522,
#     'precision_cv': 0.657121212121212,
#     'recall_cv': 0.5846153846153846,
#     'f1_cv': 0.6143722943722943,
#     'accuracy_val': 0.8888888888888888,
#     'precision_val': 0.9230769230769231,
#     'recall_val': 0.8,
#     'f1_val': 0.8571428571428571},
#    'Naive Bayes': {'accuracy_cv': 0.6302955665024631,
#     'precision_cv': 0.6511904761904762,
#     'recall_cv': 0.3846153846153846,
#     'f1_cv': 0.4817726133515607,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 1.0,
#     'recall_val': 0.26666666666666666,
#     'f1_val': 0.42105263157894735}}},
#  {'random_state': 25,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6783251231527094,
#     'precision_cv': 0.6743589743589743,
#     'recall_cv': 0.5384615384615385,
#     'f1_cv': 0.5971333014811275,
#     'accuracy_val': 0.4722222222222222,
#     'precision_val': 0.42857142857142855,
#     'recall_val': 0.35294117647058826,
#     'f1_val': 0.3870967741935484},
#    'Random Forest': {'accuracy_cv': 0.7482758620689655,
#     'precision_cv': 0.7092874445815622,
# ...
#     'recall_cv': 0.667032967032967,
#     'f1_cv': 0.6636251105216622,
#     'accuracy_val': 0.6111111111111112,
#     'precision_val': 0.6428571428571429,
#     'recall_val': 0.5,
#     'f1_val': 0.5625},
#    'Decision Tree': {'accuracy_cv': 0.7546798029556651,
#     'precision_cv': 0.760989010989011,
#     'recall_cv': 0.6659340659340659,
#     'f1_cv': 0.6896350277402908,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.8181818181818182,
#     'recall_val': 0.5,
#     'f1_val': 0.6206896551724138},
#    'Naive Bayes': {'accuracy_cv': 0.6295566502463055,
#     'precision_cv': 0.6074947274947274,
#     'recall_cv': 0.4417582417582417,
#     'f1_cv': 0.50000555000555,
#     'accuracy_val': 0.6111111111111112,
#     'precision_val': 0.7,
#     'recall_val': 0.3888888888888889,
#     'f1_val': 0.5}}},
#  {'random_state': 43,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6785714285714285,
#     'precision_cv': 0.6551452159811293,
#     'recall_cv': 0.7314285714285715,
#     'f1_cv': 0.6873390050809405,
#     'accuracy_val': 0.5277777777777778,
#     'precision_val': 0.4,
#     'recall_val': 0.6153846153846154,
#     'f1_val': 0.48484848484848486},
#    'Random Forest': {'accuracy_cv': 0.7206896551724138,
#     'precision_cv': 0.7444300144300144,
#     'recall_cv': 0.6752380952380952,
#     'f1_cv': 0.69760656010656,
#     'accuracy_val': 0.5277777777777778,
#     'precision_val': 0.4090909090909091,
#     'recall_val': 0.6923076923076923,
#     'f1_val': 0.5142857142857142},
#    'Support Vector Machine': {'accuracy_cv': 0.6635467980295566,
#     'precision_cv': 0.7555555555555555,
#     'recall_cv': 0.4628571428571428,
#     'f1_cv': 0.5696179183135703,
#     'accuracy_val': 0.7222222222222222,
#     'precision_val': 0.6363636363636364,
#     'recall_val': 0.5384615384615384,
#     'f1_val': 0.5833333333333334},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.6857142857142857,
#     'precision_cv': 0.6923512452459821,
#     'recall_cv': 0.7038095238095238,
#     'f1_cv': 0.6929877544887686,
#     'accuracy_val': 0.6388888888888888,
#     'precision_val': 0.5,
#     'recall_val': 0.6923076923076923,
#     'f1_val': 0.5806451612903226},
#    'Decision Tree': {'accuracy_cv': 0.6719211822660098,
#     'precision_cv': 0.7144419306184012,
#     'recall_cv': 0.5914285714285714,
#     'f1_cv': 0.6585560675883256,
#     'accuracy_val': 0.5833333333333334,
#     'precision_val': 0.4375,
#     'recall_val': 0.5384615384615384,
#     'f1_val': 0.4827586206896552},
#    'Naive Bayes': {'accuracy_cv': 0.6852216748768474,
#     'precision_cv': 0.7193650793650794,
#     'recall_cv': 0.5895238095238095,
#     'f1_cv': 0.6422153209109731,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.5833333333333334,
#     'recall_val': 0.5384615384615384,
#     'f1_val': 0.56}}},
#  {'random_state': 44,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.5874384236453202,
#     'precision_cv': 0.5149999999999999,
#     'recall_cv': 0.39615384615384613,
#     'f1_cv': 0.4301276065981948,
#     'accuracy_val': 0.8055555555555556,
#     'precision_val': 0.8571428571428571,
#     'recall_val': 0.7058823529411765,
#     'f1_val': 0.7741935483870968},
#    'Random Forest': {'accuracy_cv': 0.6504926108374385,
#     'precision_cv': 0.627457264957265,
#     'recall_cv': 0.6076923076923076,
#     'f1_cv': 0.5574380395433026,
#     'accuracy_val': 0.7777777777777778,
#     'precision_val': 0.7647058823529411,
#     'recall_val': 0.7647058823529411,
#     'f1_val': 0.7647058823529411},
#    'Support Vector Machine': {'accuracy_cv': 0.5596059113300493,
#     'precision_cv': 0.16666666666666666,
#     'recall_cv': 0.05,
#     'f1_cv': 0.07666666666666666,
#     'accuracy_val': 0.5833333333333334,
#     'precision_val': 1.0,
#     'recall_val': 0.11764705882352941,
#     'f1_val': 0.21052631578947367},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.6714285714285714,
#     'precision_cv': 0.6400854700854701,
#     'recall_cv': 0.573076923076923,
#     'f1_cv': 0.6021385281385282,
#     'accuracy_val': 0.6388888888888888,
#     'precision_val': 0.625,
#     'recall_val': 0.5882352941176471,
#     'f1_val': 0.6060606060606061},
#    'Decision Tree': {'accuracy_cv': 0.6864532019704433,
#     'precision_cv': 0.6325274725274725,
#     'recall_cv': 0.5256410256410257,
#     'f1_cv': 0.5601525968584793,
#     'accuracy_val': 0.6666666666666666,
#     'precision_val': 0.6470588235294118,
#     'recall_val': 0.6470588235294118,
#     'f1_val': 0.6470588235294118},
#    'Naive Bayes': {'accuracy_cv': 0.6076354679802957,
#     'precision_cv': 0.6083333333333333,
#     'recall_cv': 0.3128205128205128,
#     'f1_cv': 0.4027926322043969,
#     'accuracy_val': 0.7222222222222222,
#     'precision_val': 1.0,
#     'recall_val': 0.4117647058823529,
#     'f1_val': 0.5833333333333334}}},
#  {'random_state': 45,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6576354679802956,
#     'precision_cv': 0.6882575757575757,
#     'recall_cv': 0.5857142857142857,
#     'f1_cv': 0.6144615384615384,
#     'accuracy_val': 0.5555555555555556,
#     'precision_val': 0.5882352941176471,
#     'recall_val': 0.5263157894736842,
#     'f1_val': 0.5555555555555556},
#    'Random Forest': {'accuracy_cv': 0.6997536945812808,
#     'precision_cv': 0.6980693815987934,
#     'recall_cv': 0.6714285714285715,
#     'f1_cv': 0.6898094731436125,
#     'accuracy_val': 0.7222222222222222,
#     'precision_val': 0.7647058823529411,
#     'recall_val': 0.6842105263157895,
#     'f1_val': 0.7222222222222222},
#    'Support Vector Machine': {'accuracy_cv': 0.6509852216748768,
#     'precision_cv': 0.7833333333333333,
#     'recall_cv': 0.38571428571428573,
#     'f1_cv': 0.5075362318840579,
#     'accuracy_val': 0.5555555555555556,
#     'precision_val': 0.6666666666666666,
#     'recall_val': 0.3157894736842105,
#     'f1_val': 0.42857142857142855},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.6931034482758621,
#     'precision_cv': 0.7215384615384617,
#     'recall_cv': 0.6285714285714286,
#     'f1_cv': 0.660226236088305,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.75,
#     'recall_val': 0.631578947368421,
#     'f1_val': 0.6857142857142857},
#    'Decision Tree': {'accuracy_cv': 0.714039408866995,
#     'precision_cv': 0.7284126984126984,
#     'recall_cv': 0.6857142857142857,
#     'f1_cv': 0.6833943028485757,
#     'accuracy_val': 0.75,
#     'precision_val': 0.8125,
#     'recall_val': 0.6842105263157895,
#     'f1_val': 0.7428571428571429},
#    'Naive Bayes': {'accuracy_cv': 0.6785714285714286,
#     'precision_cv': 0.7714935064935066,
#     'recall_cv': 0.48571428571428577,
#     'f1_cv': 0.5922683982683983,
#     'accuracy_val': 0.4722222222222222,
#     'precision_val': 0.5,
#     'recall_val': 0.2631578947368421,
#     'f1_val': 0.3448275862068966}}},
#  {'random_state': 46,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6849753694581281,
#     'precision_cv': 0.6867443667443668,
#     'recall_cv': 0.6450549450549451,
#     'f1_cv': 0.6503218810175332,
#     'accuracy_val': 0.5833333333333334,
#     'precision_val': 0.42857142857142855,
#     'recall_val': 0.75,
#     'f1_val': 0.5454545454545454},
#    'Random Forest': {'accuracy_cv': 0.6857142857142857,
#     'precision_cv': 0.6553540903540903,
#     'recall_cv': 0.6318681318681318,
#     'f1_cv': 0.6362741731122057,
#     'accuracy_val': 0.7222222222222222,
#     'precision_val': 0.5625,
#     'recall_val': 0.75,
#     'f1_val': 0.6428571428571429},
#    'Support Vector Machine': {'accuracy_cv': 0.6359605911330048,
#     'precision_cv': 0.7328571428571429,
#     'recall_cv': 0.3901098901098901,
#     'f1_cv': 0.4819047619047619,
#     'accuracy_val': 0.6388888888888888,
#     'precision_val': 0.4444444444444444,
#     'recall_val': 0.3333333333333333,
#     'f1_val': 0.38095238095238093},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.6502463054187192,
#     'precision_cv': 0.6267765567765567,
#     'recall_cv': 0.6285714285714284,
#     'f1_cv': 0.6270211219176736,
#     'accuracy_val': 0.5833333333333334,
#     'precision_val': 0.4117647058823529,
#     'recall_val': 0.5833333333333334,
#     'f1_val': 0.4827586206896552},
#    'Decision Tree': {'accuracy_cv': 0.6652709359605912,
#     'precision_cv': 0.6440656565656566,
#     'recall_cv': 0.6483516483516484,
#     'f1_cv': 0.6303017622702297,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.5294117647058824,
#     'recall_val': 0.75,
#     'f1_val': 0.6206896551724138},
#    'Naive Bayes': {'accuracy_cv': 0.6852216748768473,
#     'precision_cv': 0.7428571428571429,
#     'recall_cv': 0.5263736263736264,
#     'f1_cv': 0.595948051948052,
#     'accuracy_val': 0.6666666666666666,
#     'precision_val': 0.5,
#     'recall_val': 0.5833333333333334,
#     'f1_val': 0.5384615384615384}}},
#  {'random_state': 47,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6711822660098522,
#     'precision_cv': 0.6834415584415583,
#     'recall_cv': 0.5802197802197802,
#     'f1_cv': 0.6219567099567099,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.5625,
#     'recall_val': 0.6923076923076923,
#     'f1_val': 0.6206896551724138},
#    'Random Forest': {'accuracy_cv': 0.7059113300492612,
#     'precision_cv': 0.6708208458208459,
#     'recall_cv': 0.6659340659340659,
#     'f1_cv': 0.6761058201058201,
#     'accuracy_val': 0.7777777777777778,
#     'precision_val': 0.631578947368421,
#     'recall_val': 0.9230769230769231,
#     'f1_val': 0.75},
#    'Support Vector Machine': {'accuracy_cv': 0.6150246305418718,
#     'precision_cv': 0.7261904761904762,
#     'recall_cv': 0.34725274725274724,
#     'f1_cv': 0.462781954887218,
#     'accuracy_val': 0.6666666666666666,
#     'precision_val': 0.6,
#     'recall_val': 0.23076923076923078,
#     'f1_val': 0.3333333333333333},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.6226600985221674,
#     'precision_cv': 0.621095571095571,
#     'recall_cv': 0.5648351648351648,
#     'f1_cv': 0.5898968464485705,
#     'accuracy_val': 0.75,
#     'precision_val': 0.6,
#     'recall_val': 0.9230769230769231,
#     'f1_val': 0.7272727272727273},
#    'Decision Tree': {'accuracy_cv': 0.670935960591133,
#     'precision_cv': 0.683076923076923,
#     'recall_cv': 0.6362637362637362,
#     'f1_cv': 0.6381508147025389,
#     'accuracy_val': 0.75,
#     'precision_val': 0.6111111111111112,
#     'recall_val': 0.8461538461538461,
#     'f1_val': 0.7096774193548387},
#    'Naive Bayes': {'accuracy_cv': 0.6007389162561576,
#     'precision_cv': 0.6433766233766234,
#     'recall_cv': 0.36153846153846153,
#     'f1_cv': 0.4531846282372598,
#     'accuracy_val': 0.5833333333333334,
#     'precision_val': 0.375,
#     'recall_val': 0.23076923076923078,
#     'f1_val': 0.2857142857142857}}},
#  {'random_state': 48,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6423645320197044,
#     'precision_cv': 0.6397435897435897,
#     'recall_cv': 0.6533333333333333,
#     'f1_cv': 0.6457710212993861,
#     'accuracy_val': 0.5555555555555556,
#     'precision_val': 0.35,
#     'recall_val': 0.7,
#     'f1_val': 0.4666666666666667},
#    'Random Forest': {'accuracy_cv': 0.7,
#     'precision_cv': 0.7505128205128205,
#     'recall_cv': 0.6819047619047619,
#     'f1_cv': 0.6784615384615383,
#     'accuracy_val': 0.75,
#     'precision_val': 0.5333333333333333,
#     'recall_val': 0.8,
#     'f1_val': 0.64},
#    'Support Vector Machine': {'accuracy_cv': 0.614039408866995,
#     'precision_cv': 0.7333333333333334,
#     'recall_cv': 0.3333333333333333,
#     'f1_cv': 0.448078529657477,
#     'accuracy_val': 0.6111111111111112,
#     'precision_val': 0.25,
#     'recall_val': 0.2,
#     'f1_val': 0.2222222222222222},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.6229064039408867,
#     'precision_cv': 0.6287024087024087,
#     'recall_cv': 0.6266666666666667,
#     'f1_cv': 0.6222116612633855,
#     'accuracy_val': 0.4722222222222222,
#     'precision_val': 0.2857142857142857,
#     'recall_val': 0.6,
#     'f1_val': 0.3870967741935484},
#    'Decision Tree': {'accuracy_cv': 0.6711822660098521,
#     'precision_cv': 0.7173593073593073,
#     'recall_cv': 0.5857142857142856,
#     'f1_cv': 0.6421212861212862,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.4666666666666667,
#     'recall_val': 0.7,
#     'f1_val': 0.56},
#    'Naive Bayes': {'accuracy_cv': 0.6423645320197042,
#     'precision_cv': 0.6974242424242425,
#     'recall_cv': 0.5009523809523809,
#     'f1_cv': 0.5804475524475524,
#     'accuracy_val': 0.5555555555555556,
#     'precision_val': 0.25,
#     'recall_val': 0.3,
#     'f1_val': 0.2727272727272727}}},
#  {'random_state': 49,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6719211822660098,
#     'precision_cv': 0.6824402068519715,
#     'recall_cv': 0.6628571428571429,
#     'f1_cv': 0.6660136777489392,
#     'accuracy_val': 0.4722222222222222,
#     'precision_val': 0.29411764705882354,
#     'recall_val': 0.4166666666666667,
#     'f1_val': 0.3448275862068966},
#    'Random Forest': {'accuracy_cv': 0.7216748768472907,
#     'precision_cv': 0.7647474747474747,
#     'recall_cv': 0.6961904761904762,
#     'f1_cv': 0.6981179739800429,
#     'accuracy_val': 0.6388888888888888,
#     'precision_val': 0.47058823529411764,
#     'recall_val': 0.6666666666666666,
#     'f1_val': 0.5517241379310345},
#    'Support Vector Machine': {'accuracy_cv': 0.5950738916256159,
#     'precision_cv': 0.7028571428571428,
#     'recall_cv': 0.29904761904761906,
#     'f1_cv': 0.414855320118478,
#     'accuracy_val': 0.6944444444444444,
#     'precision_val': 0.5555555555555556,
#     'recall_val': 0.4166666666666667,
#     'f1_val': 0.47619047619047616},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.6438423645320197,
#     'precision_cv': 0.623015873015873,
#     'recall_cv': 0.6666666666666667,
#     'f1_cv': 0.6377380952380952,
#     'accuracy_val': 0.5833333333333334,
#     'precision_val': 0.38461538461538464,
#     'recall_val': 0.4166666666666667,
#     'f1_val': 0.4},
#    'Decision Tree': {'accuracy_cv': 0.7275862068965517,
#     'precision_cv': 0.7644444444444445,
#     'recall_cv': 0.6942857142857143,
#     'f1_cv': 0.7101923076923077,
#     'accuracy_val': 0.6111111111111112,
#     'precision_val': 0.4,
#     'recall_val': 0.3333333333333333,
#     'f1_val': 0.36363636363636365},
#    'Naive Bayes': {'accuracy_cv': 0.6229064039408867,
#     'precision_cv': 0.7264069264069264,
#     'recall_cv': 0.3961904761904762,
#     'f1_cv': 0.504728778467909,
#     'accuracy_val': 0.6388888888888888,
#     'precision_val': 0.42857142857142855,
#     'recall_val': 0.25,
#     'f1_val': 0.3157894736842105}}},
#  {'random_state': 50,
#   'model_metrics': {'Logistic Regression': {'accuracy_cv': 0.6637931034482759,
#     'precision_cv': 0.6240909090909091,
#     'recall_cv': 0.55,
#     'f1_cv': 0.5776811594202897,
#     'accuracy_val': 0.6111111111111112,
#     'precision_val': 0.8125,
#     'recall_val': 0.5416666666666666,
#     'f1_val': 0.65},
#    'Random Forest': {'accuracy_cv': 0.7549261083743842,
#     'precision_cv': 0.6961904761904762,
#     'recall_cv': 0.6666666666666666,
#     'f1_cv': 0.6653805453805454,
#     'accuracy_val': 0.6666666666666666,
#     'precision_val': 0.7727272727272727,
#     'recall_val': 0.7083333333333334,
#     'f1_val': 0.7391304347826086},
#    'Support Vector Machine': {'accuracy_cv': 0.6359605911330048,
#     'precision_cv': 0.6533333333333333,
#     'recall_cv': 0.18333333333333332,
#     'f1_cv': 0.2810644257703081,
#     'accuracy_val': 0.4444444444444444,
#     'precision_val': 0.8333333333333334,
#     'recall_val': 0.20833333333333334,
#     'f1_val': 0.3333333333333333},
#    'K-Nearest Neighbors': {'accuracy_cv': 0.7403940886699507,
#     'precision_cv': 0.7506349206349208,
#     'recall_cv': 0.5999999999999999,
#     'f1_cv': 0.6564319890635679,
#     'accuracy_val': 0.5833333333333334,
#     'precision_val': 0.7368421052631579,
#     'recall_val': 0.5833333333333334,
#     'f1_val': 0.6511627906976745},
#    'Decision Tree': {'accuracy_cv': 0.7549261083743841,
#     'precision_cv': 0.7003663003663003,
#     'recall_cv': 0.65,
#     'f1_cv': 0.6751688311688312,
#     'accuracy_val': 0.6388888888888888,
#     'precision_val': 0.7619047619047619,
#     'recall_val': 0.6666666666666666,
#     'f1_val': 0.7111111111111111},
#    'Naive Bayes': {'accuracy_cv': 0.664039408866995,
#     'precision_cv': 0.6723809523809523,
#     'recall_cv': 0.4,
#     'f1_cv': 0.4973950026581605,
#     'accuracy_val': 0.5555555555555556,
#     'precision_val': 0.9,
#     'recall_val': 0.375,
#     'f1_val': 0.5294117647058824}}}]

# %%
avg_results = {
    "Classifier": [],
    "Accuracy CV Avg": [],
    "Precision CV Avg": [],
    "Recall CV Avg": [],
    "F1 Score CV Avg": [],
    "Accuracy Val Avg": [],
    "Precision Val Avg": [],
    "Recall Val Avg": [],
    "F1 Score Val Avg": []
}

# %%
for name in classifiers.keys():
    accuracy_cv_avg = np.mean([result["model_metrics"][name]["accuracy_cv"] for result in results_per_seed])
    precision_cv_avg = np.mean([result["model_metrics"][name]["precision_cv"] for result in results_per_seed])
    recall_cv_avg = np.mean([result["model_metrics"][name]["recall_cv"] for result in results_per_seed])
    f1_cv_avg = np.mean([result["model_metrics"][name]["f1_cv"] for result in results_per_seed])
    
    accuracy_val_avg = np.mean([result["model_metrics"][name]["accuracy_val"] for result in results_per_seed])
    precision_val_avg = np.mean([result["model_metrics"][name]["precision_val"] for result in results_per_seed])
    recall_val_avg = np.mean([result["model_metrics"][name]["recall_val"] for result in results_per_seed])
    f1_val_avg = np.mean([result["model_metrics"][name]["f1_val"] for result in results_per_seed])
    
    overall_kappa_avg = np.mean([result["model_metrics"][name]["Overall Average Kappa"] for result in results_per_seed])
    peer_kappa_avg = np.mean([result["model_metrics"][name]["Peer Average Kappa"] for result in results_per_seed])
    
    avg_results["Classifier"].append(name)
    avg_results["Accuracy CV Avg"].append(accuracy_cv_avg)
    avg_results["Precision CV Avg"].append(precision_cv_avg)
    avg_results["Recall CV Avg"].append(recall_cv_avg)
    avg_results["F1 Score CV Avg"].append(f1_cv_avg)
    avg_results["Accuracy Val Avg"].append(accuracy_val_avg)
    avg_results["Precision Val Avg"].append(precision_val_avg)
    avg_results["Recall Val Avg"].append(recall_val_avg)
    avg_results["F1 Score Val Avg"].append(f1_val_avg)
    avg_results["Overall Average Kappa Avg"].append(overall_kappa_avg)
    avg_results["Peer Average Kappa Avg"].append(peer_kappa_avg)

# Create DataFrame to display the results
avg_results_df = pd.DataFrame(avg_results)

# Display the results
avg_results_df
# Out:
#                Classifier  Accuracy CV Avg  Precision CV Avg  Recall CV Avg  \
# 0     Logistic Regression         0.649454          0.643465       0.575830
# 1           Random Forest         0.699015          0.689784       0.664865
# 2  Support Vector Machine         0.606718          0.684134       0.251986
# 3     K-Nearest Neighbors         0.649222          0.630347       0.609866
# 4           Decision Tree         0.689781          0.682893       0.641683
# 5             Naive Bayes         0.635009          0.670636       0.418126
#
#    F1 Score CV Avg  Accuracy Val Avg  Precision Val Avg  Recall Val Avg  \
# 0         0.594062          0.633987           0.602128        0.572706
# 1         0.665733          0.712963           0.672782        0.687649
# 2         0.345394          0.614924           0.681783        0.252392
# 3         0.612152          0.641068           0.597065        0.587608
# 4         0.652849          0.706427           0.674885        0.645964
# 5         0.500317          0.620370           0.629285        0.370551
#
#    F1 Score Val Avg
# 0          0.573589
# 1          0.671850
# 2          0.350520
# 3          0.582460
# 4          0.650871
# 5          0.451470
